# %% [markdown]
# <a href="https://colab.research.google.com/github/electrojam/Curso-de-Visualizacion-de-Datos-con-Matplotlib-y-Seaborn/blob/main/parametros.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Creamos variable tips con data precargado de seaborn
tips = sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#creamos gráfico desde seaborn
sns.displot(data=tips, x='total_bill')
plt.show()

# %%
#creamos gráfico desde seaborn relación entre dos variables total de la propina y la propina
sns.displot(data=tips, x='total_bill', y='tip')
plt.show()

# %%
#creamos gráfico desde seaborn relación tres variables total de la propina, la propina, sex
sns.displot(data=tips, x='total_bill', y='tip', hue='sex')
plt.show()

# %%
#creamos gráfico desde seaborn relación  total de la propina,
sns.displot(data=tips, x='total_bill', hue='sex')
plt.show()

# %%
#creamos gráfico tipo kde por densidad desde seaborn con total de la propina, sex
sns.displot(data=tips, x='total_bill', hue='sex', kind='kde')
plt.show()

# %%
#creamos gráfico tipo kde por densidad desde seaborn con total de la propina, sex
#Sin leyenda
sns.displot(data=tips, x='total_bill', hue='sex', kind='kde', legend=False)
plt.show()

# %%
#creamos gráfico tipo kde por densidad desde seaborn con total de la propina, sex
#Cambiamos paleta de colores a dark
sns.displot(data=tips, x='total_bill', hue='sex', kind='kde', legend='True', palette='dark')
plt.show()

# %%
#creamos gráfico tipo kde por densidad desde seaborn con total de la propina, sex
#Cambiamos paleta de colores a dark
#Hacemos más transparente alpha=0.25
sns.displot(data=tips, x='total_bill', hue='sex', kind='kde', legend='True', palette='dark', alpha=0.25)
plt.show()
